# %% [markdown]
# <a href="https://colab.research.google.com/github/mehjabeenalam-ux/Learning_Python-for-Beginners/blob/main/Ord()_Function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Python ord() function returns the Unicode code of a given single character.
#
# It is a modern encoding standard that aims to represent every character in every language.
#
# Unicode includes:
#
# - ASCII characters (first 128 code points)
# - Emojis, currency symbols, accented characters, etc.

# %% [markdown]
# Basic Ord Functions

# %%
print(ord('a'))
print(ord('A'))
print(ord('€'))

print(ord('2'))
print(ord('g'))
print(ord('&'))
# Out:
# 97
# 65
# 8364
# 50
# 103
# 38

# %% [markdown]
# Example 2: TypeError when more than one string is present

# %%
print(ord('21'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1755599766.py in <cell line: 0>()
# ----> 1 print(ord('21'))
#
# TypeError: ord() expected a character, but string of length 2 found

# %% [markdown]
# Example 3: Exploring ord() with Digits and Symbols
# This code shows that ord() value of  "A" and 'A' gives the same result.

# %%
v1 = ord("A")

v2 = ord('A')

print (v1, v2)
# Out:
# 65 65

# %% [markdown]
# Example 4: Using Both ord() and chr()
#
# - chr() function does the exact opposite of ord() function, i.e. it converts a unicode integer into a character.

# %%
v= ord("A")

print (v)

print(chr(v))
# Out:
# 65
# A
