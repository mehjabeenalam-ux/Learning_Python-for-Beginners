# %% [markdown]
# <a href="https://colab.research.google.com/github/mehjabeenalam-ux/Learning_Python-for-Beginners/blob/main/Iterators_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Iterators in Python: An iterator in Python is like a finger that points to one item at a time in a list so you can look at them one by one.
#
# An iterator is an object that contains a countable number of values.
#
# An iterator is an object that can be iterated upon, meaning that you can traverse through all the values.
#
# Technically, in Python, an iterator is an object which implements the iterator protocol, which consist of the methods __iter__() and __next__().
#
# https://www.w3schools.com/python/python_iterators.asp

# %% [markdown]
# Iterator vs Iterable
#
# Lists, tuples, dictionaries, and sets are all iterable objects. They are iterable containers which you can get an iterator from.

# %% [markdown]
# Return an iterator from a tuple, and print each value:

# %%
mytuple = ("apple", "banana", "cherry")
myit = iter(mytuple)

print(next(myit))
print(next(myit))
print(next(myit))
# Out:
# apple
# banana
# cherry

# %% [markdown]
# Even strings are iterable objects, and can return an iterator:
#
# Strings are also iterable objects, containing a sequence of characters:

# %%
mystr = "banana"
myit = iter(mystr)

print(next(myit))
print(next(myit))
print(next(myit))
print(next(myit))
print(next(myit))
print(next(myit))
# Out:
# b
# a
# n
# a
# n
# a

# %% [markdown]
# Looping Through an Iterator:
#
# We can also use a for loop to iterate through an iterable object:
#
# Iterate the values of a tuple:

# %%
mytuple = ("apple", "banana", "cherry")

for x in mytuple:
  print(x)
# Out:
# apple
# banana
# cherry

# %% [markdown]
# Iterate the characters of a string:

# %%
mystr = "banana"

for x in mystr:
  print(x)
# Out:
# b
# a
# n
# a
# n
# a

# %% [markdown]
# The for loop actually creates an iterator object and executes the next() method for each loop.
